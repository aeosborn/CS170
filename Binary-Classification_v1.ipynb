# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
from keras.models import Model
from keras.layers import Input, Dense, Dropout, BatchNormalization, Conv1D, Add, Activation, GlobalAveragePooling1D, MultiHeadAttention, LayerNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import AdamW
from keras.regularizers import l2
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier
import ta
import sys
import argparse

# Set random seeds
tf.random.set_seed(42)
np.random.seed(42)
plt.style.use('seaborn-v0_8-darkgrid')

# Environment detection for Jupyter
def is_jupyter():
    return 'ipykernel' in sys.modules or 'IPython' in sys.modules

# Argument parsing
if not is_jupyter():
    parser = argparse.ArgumentParser(description='Stacking Ensemble for Price Prediction')
    parser.add_argument('--meta-classifier', type=str, default='rf', choices=['rf', 'svm', 'xgb'],
                        help='Meta-classifier: rf (Random Forest), svm (SVM), xgb (XGBoost)')
    parser.add_argument('--verbose', action='store_true', help='Enable verbose output')
    args = parser.parse_args()
    meta_classifier = args.meta_classifier
    verbose = args.verbose
else:
    meta_classifier = 'rf'  # Default for Jupyter
    verbose = True  # Enable verbose output in Jupyter

# Data Loading
if verbose:
    print("Fetching data from yfinance...")
try:
    eth_data = yf.download('ETH-USD', start='2021-01-01', end='2023-01-01', interval='1d')
except Exception as e:
    raise RuntimeError(f"Failed to fetch yfinance data: {e}")
eth_data.columns = [col[0] if isinstance(col, tuple) else col for col in eth_data.columns]
price_history_raw = eth_data.reset_index().rename(columns={
    'Date': 'timeOpen', 'Close': 'close', 'Open': 'open',
    'High': 'high', 'Low': 'low', 'Volume': 'volume'
})

# Debugging
if verbose:
    print("price_history_raw columns:", price_history_raw.columns)
    print("price_history_raw['close'] dtype:", price_history_raw['close'].dtype)
    print("price_history_raw shape:", price_history_raw.shape)

# Create price_deltas
price_deltas = price_history_raw[['timeOpen', 'close', 'volume', 'open', 'high', 'low']].copy()
price_deltas['close'] = pd.to_numeric(price_deltas['close'], errors='coerce')
if price_deltas['close'].isna().all():
    raise ValueError("All 'close' values are NaN.")
price_deltas['close'] = price_deltas['close'].interpolate(method='linear', limit_direction='both')
if verbose:
    print("NaNs in 'close':", price_deltas['close'].isna().sum())

# Process timeOpen
price_deltas['timeOpen'] = pd.to_datetime(price_deltas['timeOpen'], errors='coerce')
if price_deltas['timeOpen'].isna().any():
    raise ValueError("Invalid 'timeOpen' values detected.")
price_deltas['date'] = price_deltas['timeOpen'].dt.date

# Calculate price delta
price_deltas['delta'] = price_deltas['close'].pct_change()

# Feature Engineering
price_deltas['lag1_delta'] = price_deltas['delta'].shift(1)
price_deltas['lag2_delta'] = price_deltas['delta'].shift(2)
price_deltas['volatility'] = price_deltas['delta'].rolling(window=7).std()
price_deltas['volume_change'] = price_deltas['volume'].pct_change()
price_deltas['rsi'] = ta.momentum.RSIIndicator(price_deltas['close'], window=14).rsi()
price_deltas['macd'] = ta.trend.MACD(price_deltas['close']).macd()
price_deltas['bb_upper'] = ta.volatility.BollingerBands(price_deltas['close']).bollinger_hband()
price_deltas['bb_lower'] = ta.volatility.BollingerBands(price_deltas['close']).bollinger_lband()
price_deltas['obv'] = ta.volume.OnBalanceVolumeIndicator(price_deltas['close'], price_deltas['volume']).on_balance_volume()

# Fill NaNs in features
feature_cols = ['lag1_delta', 'lag2_delta', 'volatility', 'volume_change', 'rsi', 'macd', 'bb_upper', 'bb_lower', 'obv']
price_deltas[feature_cols] = price_deltas[feature_cols].fillna(method='ffill').fillna(method='bfill')

# Debugging
if verbose:
    print("\nprice_deltas shape:", price_deltas.shape)
    print("price_deltas columns:", price_deltas.columns)
    print("NaNs in features:\n", price_deltas[feature_cols].isna().sum())

# Load Whale/Validator Data
try:
    base_path = r'C:\Users\ACER 2\OneDrive\Documents\178\DATA\\'  
    whales = pd.read_csv(base_path + 'transactions_aggregated_21_22.csv')
    validators = pd.read_csv(base_path + 'validators_aggregated_21_22.csv')

except FileNotFoundError as e:
    raise FileNotFoundError(f"Could not find CSV files: {e}")
whales['date'] = pd.to_datetime(whales['datetime'], errors='coerce').dt.date
validators['date'] = pd.to_datetime(validators['datetime'], errors='coerce').dt.date
if whales['date'].isna().any() or validators['date'].isna().any():
    raise ValueError("Invalid dates in whale/validator data.")
if verbose:
    print("\nWhales date range:", whales['date'].min(), "to", whales['date'].max())
    print("Validators date range:", validators['date'].min(), "to", validators['date'].max())

# Label Generation
num_labels = 2
price_deltas['labels'] = (price_deltas['close'].diff() > 0).astype(int)
if verbose:
    print(f"Label distribution:\n{price_deltas['labels'].value_counts(normalize=True)}")

# Data Aggregation & Merging
whale_aggregated = whales.groupby('date').agg(
    whale_avg_valueEth=('valueETH', 'mean'),
    whale_var_valueEth=('valueETH', 'var'),
    whale_avg_gasPrice=('gasPrice', 'mean')
)
validators_aggregated = validators.groupby('date').agg(
    validator_count=('blockHash', 'nunique'),
    validator_gas_price=('gasPrice', 'mean')
)
_intermediate = pd.merge(price_deltas, whale_aggregated, on='date', how='left')
labeled_data = pd.merge(_intermediate, validators_aggregated, on='date', how='left')
original_features = [
    'whale_avg_valueEth', 'whale_var_valueEth', 'whale_avg_gasPrice',
    'validator_count', 'validator_gas_price', 'lag1_delta', 'lag2_delta',
    'volatility', 'volume_change', 'rsi', 'macd', 'bb_upper', 'bb_lower', 'obv'
]
labeled_data[original_features] = labeled_data[original_features].fillna(method='ffill').fillna(method='bfill')
labeled_data.dropna(subset=['labels'], inplace=True)
labeled_data.sort_values(by='date', inplace=True)
if labeled_data.empty:
    raise ValueError("labeled_data is empty after preprocessing.")
if verbose:
    print(f"Shape of labeled_data: {labeled_data.shape}")
    print(f"Features used: {original_features}")
    print("NaNs in labeled_data:\n", labeled_data[original_features].isna().sum())

# Train/Test Split & Scaling
y = labeled_data['labels'].astype(int)
X = labeled_data[original_features]
if X.shape[0] < 10:
    raise ValueError("Not enough data after merging.")
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=False)
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train_raw)
X_test = scaler.transform(X_test_raw)
X_train = pd.DataFrame(X_train, columns=original_features, index=X_train_raw.index)
X_test = pd.DataFrame(X_test, columns=original_features, index=X_test_raw.index)
if verbose:
    print(f"Training data shape: X={X_train.shape}, y={y_train.shape}")
    print(f"Testing data shape: X={X_test.shape}, y={y_test.shape}")

# Windowing
window_length = 5
input_features = X_train.shape[1]
def create_windows(data, window_size):
    windows = []
    for i in range(len(data) - window_size + 1):
        windows.append(data[i:i + window_size])
    return np.array(windows)
X_train_windowed = create_windows(X_train.values, window_length)
X_test_windowed = create_windows(X_test.values, window_length)
y_train_windowed = y_train.iloc[window_length-1:].values
y_test_windowed = y_test.iloc[window_length-1:].values
if X_train_windowed.shape[0] != y_train_windowed.shape[0]:
    raise ValueError(f"Training data mismatch: X={X_train_windowed.shape}, y={y_train_windowed.shape}")
if X_test_windowed.shape[0] != y_test_windowed.shape[0]:
    raise ValueError(f"Testing data mismatch: X={X_test_windowed.shape}, y={y_test_windowed.shape}")
if verbose:
    print(f"Windowed training data shape: X={X_train_windowed.shape}, y={y_train_windowed.shape}")
    print(f"Windowed testing data shape: X={X_test_windowed.shape}, y={y_test_windowed.shape}")
num_classes = len(np.unique(y_train_windowed))
price_deltas_test_aligned = labeled_data['delta'].loc[y_test.index[window_length-1:]].to_numpy()
if len(price_deltas_test_aligned) != len(y_test_windowed):
    raise ValueError("Price deltas and test labels length mismatch.")

# Backtesting Function
def calculate_model_returns(predictions, price_deltas, num_labels, invest_on_tie=False, plot_results=True, investment_rate=0.8):
    if len(predictions) != len(price_deltas):
        print(f"Warning: Length mismatch: predictions ({len(predictions)}), price_deltas ({len(price_deltas)})")
        return {'total_return_pct': np.nan, 'benchmark_return_pct': np.nan}
    model_history = [1]
    benchmark_history = [1]
    investing_schedule = []
    for i in range(len(predictions)):
        if np.isnan(price_deltas[i]):
            benchmark_history.append(benchmark_history[-1])
            model_history.append(model_history[-1])
            investing_schedule.append(0)
            continue
        benchmark_history.append(benchmark_history[-1] * (1 + price_deltas[i]))
        if predictions[i] == 1:
            capital_change = model_history[-1] * price_deltas[i] * investment_rate
            model_history.append(model_history[-1] + capital_change)
            investing_schedule.append(1)
        else:
            model_history.append(model_history[-1])
            investing_schedule.append(0)
    total_return_pct = (model_history[-1] - 1) * 100
    benchmark_return_pct = (benchmark_history[-1] - 1) * 100
    if plot_results:
        plt.figure(figsize=(12, 6))
        plt.plot(model_history, label='Model Strategy', color='blue', marker='.')
        plt.plot(benchmark_history, label='Benchmark', color='red', linestyle='--', marker='.')
        for i, invested in enumerate(investing_schedule):
            if invested == 1:
                plt.axvspan(i, i + 1, color='green', alpha=0.3)
        plt.title(f'Results\nModel Return: {total_return_pct:.2f}%, Benchmark: {benchmark_return_pct:.2f}%')
        plt.xlabel('Trading Days')
        plt.ylabel('Capital ($)')
        plt.yscale('log')
        plt.grid(True)
        plt.legend()
        plt.show()
    return {'total_return_pct': total_return_pct, 'benchmark_return_pct': benchmark_return_pct}

# TCN Model
def residual_block(x, filters, kernel_size, dilation_rate, dropout_rate=0.3):
    prev_x = x
    if x.shape[-1] != filters:
        prev_x = Conv1D(filters, kernel_size=1, padding='same', kernel_regularizer=l2(0.01))(prev_x)
    conv1 = Conv1D(filters, kernel_size, dilation_rate=dilation_rate, padding='causal', kernel_regularizer=l2(0.01))(x)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Dropout(dropout_rate)(conv1)
    conv2 = Conv1D(filters, kernel_size, dilation_rate=dilation_rate, padding='causal', kernel_regularizer=l2(0.01))(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Dropout(dropout_rate)(conv2)
    out = Add()([prev_x, conv2])
    out = Activation('relu')(out)
    return out

def build_enhanced_tcn(window_length, input_features, num_classes):
    inputs = Input(shape=(window_length, input_features))
    x = inputs
    for d in [1, 2]:
        x = residual_block(x, filters=16, kernel_size=3, dilation_rate=d)
    x = GlobalAveragePooling1D()(x)
    outputs = Dense(num_classes, activation='softmax', kernel_regularizer=l2(0.01))(x)
    return Model(inputs, outputs, name="Enhanced_TCN")

# Transformer Model
def build_transformer(window_length, input_features, num_classes):
    inputs = Input(shape=(window_length, input_features))
    x = inputs
    for _ in range(1):
        attn_output = MultiHeadAttention(num_heads=2, key_dim=16)(x, x)
        x = LayerNormalization(epsilon=1e-6)(x + attn_output)
        ffn = Dense(32, activation='relu', kernel_regularizer=l2(0.01))(x)
        ffn = Dense(input_features, kernel_regularizer=l2(0.01))(ffn)
        x = LayerNormalization(epsilon=1e-6)(x + ffn)
    x = GlobalAveragePooling1D()(x)
    outputs = Dense(num_classes, activation='softmax', kernel_regularizer=l2(0.01))(x)
    return Model(inputs, outputs, name="Transformer")

# Training & Prediction for Base Models
def train_predict_base_model(model_name, model, X_train_data, y_train_data, X_test_data, tscv, model_type='keras', epochs=50, batch_size=32):
    if verbose:
        print(f"\n--- Training Base Model: {model_name} ---")
    train_preds = np.zeros(len(y_train_data))
    test_preds = np.zeros(len(X_test_data))
    fold_test_preds = []
    
    if model_type == 'keras':
        for fold, (train_idx, val_idx) in enumerate(tscv.split(X_train_data)):
            X_tr, X_val = X_train_data[train_idx], X_train_data[val_idx]
            y_tr, y_val = y_train_data[train_idx], y_train_data[val_idx]
            model_fold = tf.keras.models.clone_model(model)
            model_fold.compile(optimizer=AdamW(learning_rate=0.0005), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
            class_weights = compute_class_weight('balanced', classes=np.unique(y_tr), y=y_tr)
            class_weight_dict = dict(enumerate(class_weights))
            model_fold.fit(
                X_tr, y_tr, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val),
                callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1 if verbose else 0),
                           ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1 if verbose else 0)],
                class_weight=class_weight_dict, verbose=1 if verbose else 0
            )
            train_preds[val_idx] = np.argmax(model_fold.predict(X_val, verbose=0), axis=1)
            fold_test_preds.append(np.argmax(model_fold.predict(X_test_data, verbose=0), axis=1))
        test_preds = np.mean(fold_test_preds, axis=0).round().astype(int)
    else:
        for fold, (train_idx, val_idx) in enumerate(tscv.split(X_train_data)):
            X_tr, X_val = X_train_data[train_idx], X_train_data[val_idx]
            y_tr, y_val = y_train_data[train_idx], y_train_data[val_idx]
            model.fit(X_tr, y_tr)
            train_preds[val_idx] = model.predict(X_val)
            fold_test_preds.append(model.predict(X_test_data))
        test_preds = np.apply_along_axis(lambda x: np.bincount(x).argmax(), axis=0, arr=fold_test_preds)
    
    return train_preds, test_preds

# Stacking Ensemble
def train_stacking_ensemble(X_train_windowed, y_train_windowed, X_test_windowed, y_test_windowed, price_deltas_test_aligned, num_labels):
    tscv = TimeSeriesSplit(n_splits=5)
    
    # Initialize base models
    tcn_model = build_enhanced_tcn(window_length, input_features, num_classes)
    transformer_model = build_transformer(window_length, input_features, num_classes)
    xgb_model = XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)
    
    # Get base model predictions
    tcn_train_preds, tcn_test_preds = train_predict_base_model(
        "Enhanced TCN", tcn_model, X_train_windowed, y_train_windowed, X_test_windowed, tscv
    )
    transformer_train_preds, transformer_test_preds = train_predict_base_model(
        "Transformer", transformer_model, X_train_windowed, y_train_windowed, X_test_windowed, tscv
    )
    xgb_train_preds, xgb_test_preds = train_predict_base_model(
        "XGBoost", xgb_model, X_train_windowed.reshape(X_train_windowed.shape[0], -1),
        y_train_windowed, X_test_windowed.reshape(X_test_windowed.shape[0], -1), tscv, model_type='sklearn'
    )
    
    # Stack predictions
    train_meta_features = np.column_stack((tcn_train_preds, transformer_train_preds, xgb_train_preds))
    test_meta_features = np.column_stack((tcn_test_preds, transformer_test_preds, xgb_test_preds))
    
    # Train meta-classifier
    if meta_classifier == 'rf':
        meta_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
    elif meta_classifier == 'svm':
        meta_model = SVC(kernel='rbf', C=1.0, probability=True, random_state=42)
    else:
        meta_model = XGBClassifier(n_estimators=50, max_depth=3, learning_rate=0.1, random_state=42)
    
    if verbose:
        print(f"\n--- Training Meta-Classifier: {meta_classifier.upper()} ---")
    meta_model.fit(train_meta_features, y_train_windowed)
    
    # Evaluate ensemble
    y_pred = meta_model.predict(test_meta_features)
    accuracy = accuracy_score(y_test_windowed, y_pred)
    f1 = f1_score(y_test_windowed, y_pred, average='weighted')
    class_report = classification_report(y_test_windowed, y_pred, target_names=[f"Class_{i}" for i in range(num_classes)], zero_division=0)
    conf_matrix = confusion_matrix(y_test_windowed, y_pred)
    backtest_results = calculate_model_returns(y_pred, price_deltas_test_aligned, num_labels)
    
    if verbose:
        print(f"\nMetrics for Stacking Ensemble ({meta_classifier.upper()}):")
        print(f"Test Accuracy: {accuracy:.4f}")
        print(f"Test F1 Score: {f1:.4f}")
        print("Classification Report:")
        print(class_report)
        plt.figure(figsize=(6, 5))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title(f'Confusion Matrix - Stacking Ensemble ({meta_classifier.upper()})')
        plt.show()
        print(f"Backtest Results: {backtest_results}")
    
    return {
        'model_name': f'Stacking_{meta_classifier.upper()}',
        'test_accuracy': accuracy,
        'test_f1_weighted': f1,
        'backtest_return_pct': backtest_results.get('total_return_pct', np.nan),
        'benchmark_return_pct': backtest_results.get('benchmark_return_pct', np.nan)
    }

# Run ensemble
try:
    results = train_stacking_ensemble(X_train_windowed, y_train_windowed, X_test_windowed, y_test_windowed, price_deltas_test_aligned, num_labels)
    if verbose:
        print("\nFinal Results:")
        print(pd.DataFrame([results]).round(4))
except Exception as e:
    print(f"Error during execution: {e}")
    raise
# Out:
# Fetching data from yfinance...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# C:\Users\ACER 2\AppData\Local\Temp\ipykernel_11040\1153024634.py:96: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   price_deltas[feature_cols] = price_deltas[feature_cols].fillna(method='ffill').fillna(method='bfill')
# price_history_raw columns: Index(['timeOpen', 'close', 'high', 'low', 'open', 'volume'], dtype='object')
# price_history_raw['close'] dtype: float64
# price_history_raw shape: (730, 6)
# NaNs in 'close': 0
#
# price_deltas shape: (730, 17)
# price_deltas columns: Index(['timeOpen', 'close', 'volume', 'open', 'high', 'low', 'date', 'delta',
#        'lag1_delta', 'lag2_delta', 'volatility', 'volume_change', 'rsi',
#        'macd', 'bb_upper', 'bb_lower', 'obv'],
#       dtype='object')
# NaNs in features:
#  lag1_delta       0
# lag2_delta       0
# volatility       0
# volume_change    0
# rsi              0
# macd             0
# bb_upper         0
# bb_lower         0
# obv              0
# dtype: int64
#
# Whales date range: 2021-01-01 to 2022-12-31
# Validators date range: 2021-01-01 to 2022-12-31
# Label distribution:
# labels
# 1    0.508219
# 0    0.491781
# Name: proportion, dtype: float64
# Shape of labeled_data: (730, 23)
# Features used: ['whale_avg_valueEth', 'whale_var_valueEth', 'whale_avg_gasPrice', 'validator_count', 'validator_gas_price', 'lag1_delta', 'lag2_delta', 'volatility', 'volume_change', 'rsi', 'macd', 'bb_upper', 'bb_lower', 'obv']
# NaNs in labeled_data:
#  whale_avg_valueEth     0
# whale_var_valueEth     0
# whale_avg_gasPrice     0
# validator_count        0
# validator_gas_price    0
# lag1_delta             0
# lag2_delta             0
# volatility             0
# volume_change          0
# rsi                    0
# macd                   0
# bb_upper               0
# bb_lower               0
# obv                    0
# dtype: int64
# Training data shape: X=(511, 14), y=(511,)
# Testing data shape: X=(219, 14), y=(219,)
# Windowed training data shape: X=(507, 5, 14), y=(507,)
# Windowed testing data shape: X=(215, 5, 14), y=(215,)
# C:\Users\ACER 2\AppData\Local\Temp\ipykernel_11040\1153024634.py:143: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   labeled_data[original_features] = labeled_data[original_features].fillna(method='ffill').fillna(method='bfill')
# --- Training Base Model: Enhanced TCN ---
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.4197 - loss: 1.5766 - val_accuracy: 0.4762 - val_loss: 1.5622 - learning_rate: 5.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4349 - loss: 1.6111 - val_accuracy: 0.4762 - val_loss: 1.5540 - learning_rate: 5.0000e-04
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3827 - loss: 1.6723 - val_accuracy: 0.4762 - val_loss: 1.5457 - learning_rate: 5.0000e-04
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4312 - loss: 1.5776 - val_accuracy: 0.4643 - val_loss: 1.5374 - learning_rate: 5.0000e-04
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4332 - loss: 1.6217 - val_accuracy: 0.4524 - val_loss: 1.5294 - learning_rate: 5.0000e-04
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4640 - loss: 1.5887 - val_accuracy: 0.4405 - val_loss: 1.5215 - learning_rate: 5.0000e-04
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3169 - loss: 1.6095 - val_accuracy: 0.4405 - val_loss: 1.5139 - learning_rate: 5.0000e-04
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4178 - loss: 1.5836 - val_accuracy: 0.4405 - val_loss: 1.5067 - learning_rate: 5.0000e-04
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5433 - loss: 1.4900 - val_accuracy: 0.4643 - val_loss: 1.4996 - learning_rate: 5.0000e-04
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5238 - loss: 1.5018 - val_accuracy: 0.4762 - val_loss: 1.4929 - learning_rate: 5.0000e-04
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4638 - loss: 1.5767 - val_accuracy: 0.4762 - val_loss: 1.4864 - learning_rate: 5.0000e-04
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4197 - loss: 1.5817 - val_accuracy: 0.4762 - val_loss: 1.4800 - learning_rate: 5.0000e-04
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4739 - loss: 1.5093 - val_accuracy: 0.4881 - val_loss: 1.4736 - learning_rate: 5.0000e-04
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4001 - loss: 1.4913 - val_accuracy: 0.4643 - val_loss: 1.4674 - learning_rate: 5.0000e-04
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4622 - loss: 1.5055 - val_accuracy: 0.4643 - val_loss: 1.4613 - learning_rate: 5.0000e-04
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4388 - loss: 1.5211 - val_accuracy: 0.4643 - val_loss: 1.4552 - learning_rate: 5.0000e-04
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4507 - loss: 1.5303 - val_accuracy: 0.4762 - val_loss: 1.4495 - learning_rate: 5.0000e-04
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4659 - loss: 1.5111 - val_accuracy: 0.4881 - val_loss: 1.4438 - learning_rate: 5.0000e-04
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4195 - loss: 1.4828 - val_accuracy: 0.5000 - val_loss: 1.4381 - learning_rate: 5.0000e-04
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5240 - loss: 1.4397 - val_accuracy: 0.5000 - val_loss: 1.4324 - learning_rate: 5.0000e-04
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5010 - loss: 1.4760 - val_accuracy: 0.5119 - val_loss: 1.4268 - learning_rate: 5.0000e-04
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5376 - loss: 1.4970 - val_accuracy: 0.5000 - val_loss: 1.4213 - learning_rate: 5.0000e-04
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5898 - loss: 1.4690 - val_accuracy: 0.5000 - val_loss: 1.4157 - learning_rate: 5.0000e-04
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4484 - loss: 1.4406 - val_accuracy: 0.5000 - val_loss: 1.4103 - learning_rate: 5.0000e-04
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4234 - loss: 1.4773 - val_accuracy: 0.5119 - val_loss: 1.4049 - learning_rate: 5.0000e-04
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4604 - loss: 1.4307 - val_accuracy: 0.5119 - val_loss: 1.3997 - learning_rate: 5.0000e-04
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5376 - loss: 1.3933 - val_accuracy: 0.5119 - val_loss: 1.3946 - learning_rate: 5.0000e-04
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4484 - loss: 1.4532 - val_accuracy: 0.4881 - val_loss: 1.3894 - learning_rate: 5.0000e-04
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5107 - loss: 1.4242 - val_accuracy: 0.5000 - val_loss: 1.3846 - learning_rate: 5.0000e-04
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4797 - loss: 1.3844 - val_accuracy: 0.5000 - val_loss: 1.3797 - learning_rate: 5.0000e-04
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4503 - loss: 1.4684 - val_accuracy: 0.5000 - val_loss: 1.3748 - learning_rate: 5.0000e-04
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5008 - loss: 1.3937 - val_accuracy: 0.5000 - val_loss: 1.3700 - learning_rate: 5.0000e-04
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4385 - loss: 1.4400 - val_accuracy: 0.5000 - val_loss: 1.3651 - learning_rate: 5.0000e-04
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4948 - loss: 1.4069 - val_accuracy: 0.5000 - val_loss: 1.3602 - learning_rate: 5.0000e-04
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5240 - loss: 1.3984 - val_accuracy: 0.5000 - val_loss: 1.3552 - learning_rate: 5.0000e-04
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5259 - loss: 1.3917 - val_accuracy: 0.4881 - val_loss: 1.3502 - learning_rate: 5.0000e-04
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5665 - loss: 1.3501 - val_accuracy: 0.5000 - val_loss: 1.3453 - learning_rate: 5.0000e-04
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4388 - loss: 1.4082 - val_accuracy: 0.5000 - val_loss: 1.3404 - learning_rate: 5.0000e-04
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4583 - loss: 1.3828 - val_accuracy: 0.5000 - val_loss: 1.3355 - learning_rate: 5.0000e-04
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5031 - loss: 1.3638 - val_accuracy: 0.4762 - val_loss: 1.3309 - learning_rate: 5.0000e-04
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5452 - loss: 1.3063 - val_accuracy: 0.4762 - val_loss: 1.3263 - learning_rate: 5.0000e-04
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5144 - loss: 1.3340 - val_accuracy: 0.4762 - val_loss: 1.3217 - learning_rate: 5.0000e-04
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5916 - loss: 1.3076 - val_accuracy: 0.4762 - val_loss: 1.3172 - learning_rate: 5.0000e-04
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5858 - loss: 1.3210 - val_accuracy: 0.4881 - val_loss: 1.3127 - learning_rate: 5.0000e-04
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6132 - loss: 1.2821 - val_accuracy: 0.5000 - val_loss: 1.3084 - learning_rate: 5.0000e-04
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5339 - loss: 1.3160 - val_accuracy: 0.5119 - val_loss: 1.3041 - learning_rate: 5.0000e-04
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5316 - loss: 1.3353 - val_accuracy: 0.5119 - val_loss: 1.2999 - learning_rate: 5.0000e-04
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5321 - loss: 1.2974 - val_accuracy: 0.5119 - val_loss: 1.2957 - learning_rate: 5.0000e-04
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4850 - loss: 1.3195 - val_accuracy: 0.5119 - val_loss: 1.2916 - learning_rate: 5.0000e-04
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6438 - loss: 1.2788 - val_accuracy: 0.4881 - val_loss: 1.2875 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.5161 - loss: 2.5905 - val_accuracy: 0.5833 - val_loss: 1.6655 - learning_rate: 5.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5107 - loss: 2.3853 - val_accuracy: 0.5833 - val_loss: 1.6281 - learning_rate: 5.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5084 - loss: 2.2613 - val_accuracy: 0.5833 - val_loss: 1.5960 - learning_rate: 5.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5261 - loss: 2.2186 - val_accuracy: 0.5833 - val_loss: 1.5667 - learning_rate: 5.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5139 - loss: 2.0906 - val_accuracy: 0.5833 - val_loss: 1.5409 - learning_rate: 5.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5144 - loss: 2.0357 - val_accuracy: 0.5833 - val_loss: 1.5186 - learning_rate: 5.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4976 - loss: 1.9438 - val_accuracy: 0.5952 - val_loss: 1.4990 - learning_rate: 5.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5032 - loss: 1.8796 - val_accuracy: 0.6071 - val_loss: 1.4823 - learning_rate: 5.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4741 - loss: 1.8113 - val_accuracy: 0.5952 - val_loss: 1.4687 - learning_rate: 5.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5080 - loss: 1.7318 - val_accuracy: 0.5952 - val_loss: 1.4583 - learning_rate: 5.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4432 - loss: 1.7132 - val_accuracy: 0.6190 - val_loss: 1.4502 - learning_rate: 5.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4658 - loss: 1.7635 - val_accuracy: 0.5952 - val_loss: 1.4440 - learning_rate: 5.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5669 - loss: 1.5772 - val_accuracy: 0.5952 - val_loss: 1.4391 - learning_rate: 5.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5186 - loss: 1.5713 - val_accuracy: 0.5476 - val_loss: 1.4349 - learning_rate: 5.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5542 - loss: 1.5683 - val_accuracy: 0.5357 - val_loss: 1.4306 - learning_rate: 5.0000e-04
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5349 - loss: 1.5703 - val_accuracy: 0.5357 - val_loss: 1.4259 - learning_rate: 5.0000e-04
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6016 - loss: 1.4558 - val_accuracy: 0.5357 - val_loss: 1.4211 - learning_rate: 5.0000e-04
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5255 - loss: 1.5026 - val_accuracy: 0.5476 - val_loss: 1.4166 - learning_rate: 5.0000e-04
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4854 - loss: 1.5605 - val_accuracy: 0.5476 - val_loss: 1.4129 - learning_rate: 5.0000e-04
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5265 - loss: 1.4586 - val_accuracy: 0.5476 - val_loss: 1.4090 - learning_rate: 5.0000e-04
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5580 - loss: 1.4667 - val_accuracy: 0.5357 - val_loss: 1.4046 - learning_rate: 5.0000e-04
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5446 - loss: 1.5102 - val_accuracy: 0.5238 - val_loss: 1.4001 - learning_rate: 5.0000e-04
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5131 - loss: 1.4967 - val_accuracy: 0.5119 - val_loss: 1.3960 - learning_rate: 5.0000e-04
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5004 - loss: 1.4905 - val_accuracy: 0.5119 - val_loss: 1.3917 - learning_rate: 5.0000e-04
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5780 - loss: 1.4257 - val_accuracy: 0.5357 - val_loss: 1.3867 - learning_rate: 5.0000e-04
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5405 - loss: 1.4019 - val_accuracy: 0.5357 - val_loss: 1.3813 - learning_rate: 5.0000e-04
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5392 - loss: 1.4423 - val_accuracy: 0.5357 - val_loss: 1.3765 - learning_rate: 5.0000e-04
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5576 - loss: 1.4394 - val_accuracy: 0.5119 - val_loss: 1.3717 - learning_rate: 5.0000e-04
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5159 - loss: 1.4451 - val_accuracy: 0.5000 - val_loss: 1.3658 - learning_rate: 5.0000e-04
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5315 - loss: 1.3672 - val_accuracy: 0.5119 - val_loss: 1.3602 - learning_rate: 5.0000e-04
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5759 - loss: 1.3666 - val_accuracy: 0.5238 - val_loss: 1.3551 - learning_rate: 5.0000e-04
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5940 - loss: 1.3730 - val_accuracy: 0.5119 - val_loss: 1.3505 - learning_rate: 5.0000e-04
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5211 - loss: 1.4361 - val_accuracy: 0.5238 - val_loss: 1.3461 - learning_rate: 5.0000e-04
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5548 - loss: 1.3694 - val_accuracy: 0.5238 - val_loss: 1.3417 - learning_rate: 5.0000e-04
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5654 - loss: 1.3374 - val_accuracy: 0.5357 - val_loss: 1.3370 - learning_rate: 5.0000e-04
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5645 - loss: 1.3115 - val_accuracy: 0.5238 - val_loss: 1.3310 - learning_rate: 5.0000e-04
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5773 - loss: 1.3451 - val_accuracy: 0.5119 - val_loss: 1.3258 - learning_rate: 5.0000e-04
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5530 - loss: 1.3330 - val_accuracy: 0.5238 - val_loss: 1.3205 - learning_rate: 5.0000e-04
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5371 - loss: 1.3140 - val_accuracy: 0.5238 - val_loss: 1.3152 - learning_rate: 5.0000e-04
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5620 - loss: 1.3700 - val_accuracy: 0.5238 - val_loss: 1.3108 - learning_rate: 5.0000e-04
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5292 - loss: 1.3533 - val_accuracy: 0.5238 - val_loss: 1.3066 - learning_rate: 5.0000e-04
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5798 - loss: 1.3193 - val_accuracy: 0.5238 - val_loss: 1.3021 - learning_rate: 5.0000e-04
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5918 - loss: 1.3141 - val_accuracy: 0.5476 - val_loss: 1.2977 - learning_rate: 5.0000e-04
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6588 - loss: 1.2587 - val_accuracy: 0.5476 - val_loss: 1.2930 - learning_rate: 5.0000e-04
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6804 - loss: 1.2842 - val_accuracy: 0.5476 - val_loss: 1.2880 - learning_rate: 5.0000e-04
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5475 - loss: 1.3060 - val_accuracy: 0.5595 - val_loss: 1.2834 - learning_rate: 5.0000e-04
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5972 - loss: 1.2991 - val_accuracy: 0.5714 - val_loss: 1.2788 - learning_rate: 5.0000e-04
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5502 - loss: 1.2665 - val_accuracy: 0.5476 - val_loss: 1.2748 - learning_rate: 5.0000e-04
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6171 - loss: 1.2225 - val_accuracy: 0.5595 - val_loss: 1.2707 - learning_rate: 5.0000e-04
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5599 - loss: 1.2588 - val_accuracy: 0.5595 - val_loss: 1.2668 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.4365 - loss: 2.6652 - val_accuracy: 0.4881 - val_loss: 1.7691 - learning_rate: 5.0000e-04
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4365 - loss: 2.5759 - val_accuracy: 0.4881 - val_loss: 1.7272 - learning_rate: 5.0000e-04
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4365 - loss: 2.3722 - val_accuracy: 0.4881 - val_loss: 1.6906 - learning_rate: 5.0000e-04
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4365 - loss: 2.2986 - val_accuracy: 0.4881 - val_loss: 1.6579 - learning_rate: 5.0000e-04
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4365 - loss: 2.1160 - val_accuracy: 0.4881 - val_loss: 1.6279 - learning_rate: 5.0000e-04
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4365 - loss: 2.0138 - val_accuracy: 0.4881 - val_loss: 1.6013 - learning_rate: 5.0000e-04
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4365 - loss: 1.9445 - val_accuracy: 0.4881 - val_loss: 1.5774 - learning_rate: 5.0000e-04
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4365 - loss: 1.8144 - val_accuracy: 0.4881 - val_loss: 1.5552 - learning_rate: 5.0000e-04
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4365 - loss: 1.7242 - val_accuracy: 0.4881 - val_loss: 1.5354 - learning_rate: 5.0000e-04
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4321 - loss: 1.6537 - val_accuracy: 0.4881 - val_loss: 1.5160 - learning_rate: 5.0000e-04
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4391 - loss: 1.6167 - val_accuracy: 0.4881 - val_loss: 1.4987 - learning_rate: 5.0000e-04
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4352 - loss: 1.5443 - val_accuracy: 0.4881 - val_loss: 1.4819 - learning_rate: 5.0000e-04
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4715 - loss: 1.4914 - val_accuracy: 0.4881 - val_loss: 1.4664 - learning_rate: 5.0000e-04
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4504 - loss: 1.5118 - val_accuracy: 0.4881 - val_loss: 1.4520 - learning_rate: 5.0000e-04
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4479 - loss: 1.4402 - val_accuracy: 0.4881 - val_loss: 1.4389 - learning_rate: 5.0000e-04
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4542 - loss: 1.4329 - val_accuracy: 0.4881 - val_loss: 1.4272 - learning_rate: 5.0000e-04
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4920 - loss: 1.3809 - val_accuracy: 0.4881 - val_loss: 1.4169 - learning_rate: 5.0000e-04
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4264 - loss: 1.4157 - val_accuracy: 0.4881 - val_loss: 1.4068 - learning_rate: 5.0000e-04
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4923 - loss: 1.3510 - val_accuracy: 0.4881 - val_loss: 1.3961 - learning_rate: 5.0000e-04
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5020 - loss: 1.3472 - val_accuracy: 0.4881 - val_loss: 1.3862 - learning_rate: 5.0000e-04
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5110 - loss: 1.3469 - val_accuracy: 0.4881 - val_loss: 1.3771 - learning_rate: 5.0000e-04
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5004 - loss: 1.3828 - val_accuracy: 0.4881 - val_loss: 1.3666 - learning_rate: 5.0000e-04
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5218 - loss: 1.3200 - val_accuracy: 0.4881 - val_loss: 1.3580 - learning_rate: 5.0000e-04
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5266 - loss: 1.3119 - val_accuracy: 0.4881 - val_loss: 1.3493 - learning_rate: 5.0000e-04
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5253 - loss: 1.2932 - val_accuracy: 0.4881 - val_loss: 1.3404 - learning_rate: 5.0000e-04
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5184 - loss: 1.2871 - val_accuracy: 0.4881 - val_loss: 1.3307 - learning_rate: 5.0000e-04
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5108 - loss: 1.2747 - val_accuracy: 0.4881 - val_loss: 1.3200 - learning_rate: 5.0000e-04
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5294 - loss: 1.2852 - val_accuracy: 0.4881 - val_loss: 1.3101 - learning_rate: 5.0000e-04
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5323 - loss: 1.2916 - val_accuracy: 0.4881 - val_loss: 1.3004 - learning_rate: 5.0000e-04
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5198 - loss: 1.2810 - val_accuracy: 0.4881 - val_loss: 1.2908 - learning_rate: 5.0000e-04
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5786 - loss: 1.2574 - val_accuracy: 0.5000 - val_loss: 1.2816 - learning_rate: 5.0000e-04
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5545 - loss: 1.2468 - val_accuracy: 0.4881 - val_loss: 1.2722 - learning_rate: 5.0000e-04
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5338 - loss: 1.2533 - val_accuracy: 0.4881 - val_loss: 1.2630 - learning_rate: 5.0000e-04
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4905 - loss: 1.2477 - val_accuracy: 0.4881 - val_loss: 1.2550 - learning_rate: 5.0000e-04
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5692 - loss: 1.2298 - val_accuracy: 0.4881 - val_loss: 1.2468 - learning_rate: 5.0000e-04
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5459 - loss: 1.2168 - val_accuracy: 0.4881 - val_loss: 1.2387 - learning_rate: 5.0000e-04
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5908 - loss: 1.1956 - val_accuracy: 0.4881 - val_loss: 1.2309 - learning_rate: 5.0000e-04
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5621 - loss: 1.1789 - val_accuracy: 0.4881 - val_loss: 1.2245 - learning_rate: 5.0000e-04
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5785 - loss: 1.2042 - val_accuracy: 0.4881 - val_loss: 1.2176 - learning_rate: 5.0000e-04
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6070 - loss: 1.1960 - val_accuracy: 0.4881 - val_loss: 1.2103 - learning_rate: 5.0000e-04
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5729 - loss: 1.1708 - val_accuracy: 0.5000 - val_loss: 1.2030 - learning_rate: 5.0000e-04
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5364 - loss: 1.1975 - val_accuracy: 0.5357 - val_loss: 1.1959 - learning_rate: 5.0000e-04
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5413 - loss: 1.1841 - val_accuracy: 0.5238 - val_loss: 1.1884 - learning_rate: 5.0000e-04
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4964 - loss: 1.1736 - val_accuracy: 0.5238 - val_loss: 1.1811 - learning_rate: 5.0000e-04
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5355 - loss: 1.1600 - val_accuracy: 0.5119 - val_loss: 1.1733 - learning_rate: 5.0000e-04
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6208 - loss: 1.1181 - val_accuracy: 0.5119 - val_loss: 1.1664 - learning_rate: 5.0000e-04
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5599 - loss: 1.1456 - val_accuracy: 0.5000 - val_loss: 1.1592 - learning_rate: 5.0000e-04
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5763 - loss: 1.1557 - val_accuracy: 0.5119 - val_loss: 1.1533 - learning_rate: 5.0000e-04
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5501 - loss: 1.1463 - val_accuracy: 0.5000 - val_loss: 1.1474 - learning_rate: 5.0000e-04
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6062 - loss: 1.1162 - val_accuracy: 0.4881 - val_loss: 1.1417 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.5521 - loss: 2.8809 - val_accuracy: 0.4643 - val_loss: 1.7137 - learning_rate: 5.0000e-04
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5521 - loss: 2.7022 - val_accuracy: 0.4643 - val_loss: 1.6372 - learning_rate: 5.0000e-04
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5521 - loss: 2.5609 - val_accuracy: 0.4643 - val_loss: 1.5818 - learning_rate: 5.0000e-04
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5521 - loss: 2.4120 - val_accuracy: 0.4762 - val_loss: 1.5402 - learning_rate: 5.0000e-04
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5521 - loss: 2.1938 - val_accuracy: 0.5119 - val_loss: 1.5079 - learning_rate: 5.0000e-04
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5521 - loss: 2.0247 - val_accuracy: 0.4762 - val_loss: 1.4846 - learning_rate: 5.0000e-04
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5465 - loss: 1.9187 - val_accuracy: 0.4167 - val_loss: 1.4677 - learning_rate: 5.0000e-04
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5702 - loss: 1.8433 - val_accuracy: 0.4405 - val_loss: 1.4546 - learning_rate: 5.0000e-04
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5515 - loss: 1.7286 - val_accuracy: 0.5357 - val_loss: 1.4448 - learning_rate: 5.0000e-04
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5414 - loss: 1.5860 - val_accuracy: 0.5000 - val_loss: 1.4370 - learning_rate: 5.0000e-04
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5557 - loss: 1.5699 - val_accuracy: 0.5238 - val_loss: 1.4298 - learning_rate: 5.0000e-04
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5493 - loss: 1.5810 - val_accuracy: 0.5119 - val_loss: 1.4228 - learning_rate: 5.0000e-04
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5380 - loss: 1.4405 - val_accuracy: 0.5000 - val_loss: 1.4160 - learning_rate: 5.0000e-04
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5130 - loss: 1.4348 - val_accuracy: 0.4881 - val_loss: 1.4062 - learning_rate: 5.0000e-04
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5224 - loss: 1.4350 - val_accuracy: 0.4881 - val_loss: 1.3956 - learning_rate: 5.0000e-04
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5911 - loss: 1.3736 - val_accuracy: 0.4881 - val_loss: 1.3846 - learning_rate: 5.0000e-04
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5320 - loss: 1.3905 - val_accuracy: 0.4881 - val_loss: 1.3722 - learning_rate: 5.0000e-04
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5891 - loss: 1.3251 - val_accuracy: 0.5000 - val_loss: 1.3608 - learning_rate: 5.0000e-04
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6046 - loss: 1.3477 - val_accuracy: 0.5119 - val_loss: 1.3513 - learning_rate: 5.0000e-04
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5661 - loss: 1.3602 - val_accuracy: 0.5119 - val_loss: 1.3436 - learning_rate: 5.0000e-04
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5868 - loss: 1.3495 - val_accuracy: 0.5119 - val_loss: 1.3359 - learning_rate: 5.0000e-04
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5285 - loss: 1.3630 - val_accuracy: 0.5119 - val_loss: 1.3268 - learning_rate: 5.0000e-04
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5509 - loss: 1.3291 - val_accuracy: 0.5119 - val_loss: 1.3171 - learning_rate: 5.0000e-04
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5765 - loss: 1.3253 - val_accuracy: 0.5119 - val_loss: 1.3082 - learning_rate: 5.0000e-04
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5606 - loss: 1.3163 - val_accuracy: 0.5000 - val_loss: 1.2986 - learning_rate: 5.0000e-04
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5850 - loss: 1.2947 - val_accuracy: 0.4881 - val_loss: 1.2896 - learning_rate: 5.0000e-04
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5949 - loss: 1.2792 - val_accuracy: 0.4881 - val_loss: 1.2810 - learning_rate: 5.0000e-04
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5786 - loss: 1.2573 - val_accuracy: 0.4881 - val_loss: 1.2725 - learning_rate: 5.0000e-04
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6470 - loss: 1.2294 - val_accuracy: 0.5000 - val_loss: 1.2653 - learning_rate: 5.0000e-04
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5489 - loss: 1.2502 - val_accuracy: 0.5000 - val_loss: 1.2575 - learning_rate: 5.0000e-04
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5846 - loss: 1.2534 - val_accuracy: 0.5000 - val_loss: 1.2494 - learning_rate: 5.0000e-04
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6319 - loss: 1.2035 - val_accuracy: 0.5119 - val_loss: 1.2411 - learning_rate: 5.0000e-04
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5729 - loss: 1.2494 - val_accuracy: 0.5476 - val_loss: 1.2337 - learning_rate: 5.0000e-04
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5729 - loss: 1.2130 - val_accuracy: 0.5357 - val_loss: 1.2262 - learning_rate: 5.0000e-04
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5677 - loss: 1.2127 - val_accuracy: 0.5238 - val_loss: 1.2190 - learning_rate: 5.0000e-04
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5731 - loss: 1.2604 - val_accuracy: 0.5357 - val_loss: 1.2131 - learning_rate: 5.0000e-04
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6065 - loss: 1.1701 - val_accuracy: 0.5119 - val_loss: 1.2069 - learning_rate: 5.0000e-04
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5836 - loss: 1.1783 - val_accuracy: 0.5119 - val_loss: 1.2005 - learning_rate: 5.0000e-04
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5931 - loss: 1.1750 - val_accuracy: 0.5238 - val_loss: 1.1934 - learning_rate: 5.0000e-04
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6323 - loss: 1.1528 - val_accuracy: 0.5119 - val_loss: 1.1859 - learning_rate: 5.0000e-04
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5651 - loss: 1.1526 - val_accuracy: 0.5000 - val_loss: 1.1784 - learning_rate: 5.0000e-04
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6284 - loss: 1.1502 - val_accuracy: 0.5238 - val_loss: 1.1719 - learning_rate: 5.0000e-04
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6356 - loss: 1.1463 - val_accuracy: 0.5119 - val_loss: 1.1660 - learning_rate: 5.0000e-04
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6636 - loss: 1.1205 - val_accuracy: 0.5000 - val_loss: 1.1603 - learning_rate: 5.0000e-04
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6470 - loss: 1.1421 - val_accuracy: 0.5000 - val_loss: 1.1544 - learning_rate: 5.0000e-04
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6061 - loss: 1.1088 - val_accuracy: 0.5119 - val_loss: 1.1485 - learning_rate: 5.0000e-04
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6071 - loss: 1.1127 - val_accuracy: 0.4881 - val_loss: 1.1431 - learning_rate: 5.0000e-04
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6227 - loss: 1.1032 - val_accuracy: 0.4762 - val_loss: 1.1378 - learning_rate: 5.0000e-04
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6199 - loss: 1.0883 - val_accuracy: 0.4762 - val_loss: 1.1327 - learning_rate: 5.0000e-04
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6063 - loss: 1.1352 - val_accuracy: 0.4762 - val_loss: 1.1279 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.5339 - loss: 1.6621 - val_accuracy: 0.5357 - val_loss: 1.5148 - learning_rate: 5.0000e-04
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5601 - loss: 1.6012 - val_accuracy: 0.5357 - val_loss: 1.4895 - learning_rate: 5.0000e-04
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5703 - loss: 1.5488 - val_accuracy: 0.5476 - val_loss: 1.4659 - learning_rate: 5.0000e-04
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5624 - loss: 1.5265 - val_accuracy: 0.5476 - val_loss: 1.4446 - learning_rate: 5.0000e-04
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5482 - loss: 1.4897 - val_accuracy: 0.5595 - val_loss: 1.4251 - learning_rate: 5.0000e-04
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5413 - loss: 1.4442 - val_accuracy: 0.5357 - val_loss: 1.4078 - learning_rate: 5.0000e-04
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5703 - loss: 1.4473 - val_accuracy: 0.5476 - val_loss: 1.3909 - learning_rate: 5.0000e-04
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6000 - loss: 1.4099 - val_accuracy: 0.5595 - val_loss: 1.3748 - learning_rate: 5.0000e-04
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5712 - loss: 1.3992 - val_accuracy: 0.5595 - val_loss: 1.3598 - learning_rate: 5.0000e-04
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6012 - loss: 1.3901 - val_accuracy: 0.5833 - val_loss: 1.3454 - learning_rate: 5.0000e-04
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5814 - loss: 1.3890 - val_accuracy: 0.5952 - val_loss: 1.3308 - learning_rate: 5.0000e-04
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5963 - loss: 1.3378 - val_accuracy: 0.6190 - val_loss: 1.3161 - learning_rate: 5.0000e-04
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5240 - loss: 1.3500 - val_accuracy: 0.5952 - val_loss: 1.3020 - learning_rate: 5.0000e-04
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5856 - loss: 1.3273 - val_accuracy: 0.6310 - val_loss: 1.2890 - learning_rate: 5.0000e-04
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5639 - loss: 1.3145 - val_accuracy: 0.6190 - val_loss: 1.2762 - learning_rate: 5.0000e-04
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5672 - loss: 1.2791 - val_accuracy: 0.6190 - val_loss: 1.2640 - learning_rate: 5.0000e-04
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5689 - loss: 1.2732 - val_accuracy: 0.5952 - val_loss: 1.2518 - learning_rate: 5.0000e-04
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5763 - loss: 1.2508 - val_accuracy: 0.5952 - val_loss: 1.2407 - learning_rate: 5.0000e-04
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5981 - loss: 1.2628 - val_accuracy: 0.5833 - val_loss: 1.2298 - learning_rate: 5.0000e-04
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5592 - loss: 1.2711 - val_accuracy: 0.5833 - val_loss: 1.2190 - learning_rate: 5.0000e-04
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6383 - loss: 1.1991 - val_accuracy: 0.5714 - val_loss: 1.2085 - learning_rate: 5.0000e-04
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6320 - loss: 1.1912 - val_accuracy: 0.5595 - val_loss: 1.1982 - learning_rate: 5.0000e-04
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6120 - loss: 1.1848 - val_accuracy: 0.5952 - val_loss: 1.1884 - learning_rate: 5.0000e-04
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5815 - loss: 1.1715 - val_accuracy: 0.5952 - val_loss: 1.1789 - learning_rate: 5.0000e-04
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6002 - loss: 1.1771 - val_accuracy: 0.6071 - val_loss: 1.1697 - learning_rate: 5.0000e-04
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5927 - loss: 1.1842 - val_accuracy: 0.5952 - val_loss: 1.1604 - learning_rate: 5.0000e-04
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5566 - loss: 1.1486 - val_accuracy: 0.5833 - val_loss: 1.1511 - learning_rate: 5.0000e-04
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5746 - loss: 1.1428 - val_accuracy: 0.5714 - val_loss: 1.1421 - learning_rate: 5.0000e-04
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6080 - loss: 1.1475 - val_accuracy: 0.5595 - val_loss: 1.1336 - learning_rate: 5.0000e-04
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6290 - loss: 1.1070 - val_accuracy: 0.5595 - val_loss: 1.1254 - learning_rate: 5.0000e-04
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6209 - loss: 1.0955 - val_accuracy: 0.5595 - val_loss: 1.1173 - learning_rate: 5.0000e-04
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5946 - loss: 1.1117 - val_accuracy: 0.5595 - val_loss: 1.1092 - learning_rate: 5.0000e-04
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5980 - loss: 1.0968 - val_accuracy: 0.5714 - val_loss: 1.1013 - learning_rate: 5.0000e-04
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6487 - loss: 1.0636 - val_accuracy: 0.5595 - val_loss: 1.0937 - learning_rate: 5.0000e-04
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6115 - loss: 1.0801 - val_accuracy: 0.5595 - val_loss: 1.0865 - learning_rate: 5.0000e-04
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5654 - loss: 1.0584 - val_accuracy: 0.5833 - val_loss: 1.0796 - learning_rate: 5.0000e-04
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6237 - loss: 1.0500 - val_accuracy: 0.5833 - val_loss: 1.0722 - learning_rate: 5.0000e-04
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6137 - loss: 1.0634 - val_accuracy: 0.5833 - val_loss: 1.0649 - learning_rate: 5.0000e-04
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6208 - loss: 1.0439 - val_accuracy: 0.5952 - val_loss: 1.0590 - learning_rate: 5.0000e-04
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6236 - loss: 1.0141 - val_accuracy: 0.5833 - val_loss: 1.0525 - learning_rate: 5.0000e-04
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6358 - loss: 1.0278 - val_accuracy: 0.5833 - val_loss: 1.0454 - learning_rate: 5.0000e-04
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6172 - loss: 1.0133 - val_accuracy: 0.5833 - val_loss: 1.0384 - learning_rate: 5.0000e-04
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5952 - loss: 1.0359 - val_accuracy: 0.5833 - val_loss: 1.0314 - learning_rate: 5.0000e-04
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6282 - loss: 1.0223 - val_accuracy: 0.5714 - val_loss: 1.0260 - learning_rate: 5.0000e-04
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6300 - loss: 0.9961 - val_accuracy: 0.5714 - val_loss: 1.0199 - learning_rate: 5.0000e-04
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6174 - loss: 1.0080 - val_accuracy: 0.5714 - val_loss: 1.0142 - learning_rate: 5.0000e-04
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6378 - loss: 0.9991 - val_accuracy: 0.5714 - val_loss: 1.0086 - learning_rate: 5.0000e-04
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6357 - loss: 0.9910 - val_accuracy: 0.5595 - val_loss: 1.0035 - learning_rate: 5.0000e-04
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6330 - loss: 0.9775 - val_accuracy: 0.5476 - val_loss: 0.9982 - learning_rate: 5.0000e-04
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6099 - loss: 0.9800 - val_accuracy: 0.5476 - val_loss: 0.9929 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
#
# --- Training Base Model: Transformer ---
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.5107 - loss: 1.1740 - val_accuracy: 0.4524 - val_loss: 1.2698 - learning_rate: 5.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5107 - loss: 1.1551 - val_accuracy: 0.4643 - val_loss: 1.2617 - learning_rate: 5.0000e-04
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4875 - loss: 1.1445 - val_accuracy: 0.4881 - val_loss: 1.2542 - learning_rate: 5.0000e-04
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5203 - loss: 1.1368 - val_accuracy: 0.4762 - val_loss: 1.2470 - learning_rate: 5.0000e-04
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5436 - loss: 1.1306 - val_accuracy: 0.4643 - val_loss: 1.2395 - learning_rate: 5.0000e-04
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5417 - loss: 1.1249 - val_accuracy: 0.4881 - val_loss: 1.2317 - learning_rate: 5.0000e-04
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5417 - loss: 1.1191 - val_accuracy: 0.4762 - val_loss: 1.2237 - learning_rate: 5.0000e-04
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5649 - loss: 1.1130 - val_accuracy: 0.4762 - val_loss: 1.2158 - learning_rate: 5.0000e-04
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5649 - loss: 1.1068 - val_accuracy: 0.4762 - val_loss: 1.2082 - learning_rate: 5.0000e-04
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5553 - loss: 1.1007 - val_accuracy: 0.4762 - val_loss: 1.2011 - learning_rate: 5.0000e-04
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5553 - loss: 1.0949 - val_accuracy: 0.4762 - val_loss: 1.1945 - learning_rate: 5.0000e-04
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5417 - loss: 1.0895 - val_accuracy: 0.4643 - val_loss: 1.1887 - learning_rate: 5.0000e-04
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5339 - loss: 1.0845 - val_accuracy: 0.4762 - val_loss: 1.1834 - learning_rate: 5.0000e-04
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5242 - loss: 1.0798 - val_accuracy: 0.4762 - val_loss: 1.1786 - learning_rate: 5.0000e-04
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5475 - loss: 1.0755 - val_accuracy: 0.4762 - val_loss: 1.1742 - learning_rate: 5.0000e-04
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5649 - loss: 1.0714 - val_accuracy: 0.4762 - val_loss: 1.1700 - learning_rate: 5.0000e-04
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5649 - loss: 1.0675 - val_accuracy: 0.4762 - val_loss: 1.1660 - learning_rate: 5.0000e-04
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5649 - loss: 1.0637 - val_accuracy: 0.4762 - val_loss: 1.1621 - learning_rate: 5.0000e-04
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5649 - loss: 1.0600 - val_accuracy: 0.4762 - val_loss: 1.1582 - learning_rate: 5.0000e-04
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5824 - loss: 1.0564 - val_accuracy: 0.4881 - val_loss: 1.1543 - learning_rate: 5.0000e-04
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5824 - loss: 1.0527 - val_accuracy: 0.4881 - val_loss: 1.1505 - learning_rate: 5.0000e-04
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5649 - loss: 1.0492 - val_accuracy: 0.5000 - val_loss: 1.1468 - learning_rate: 5.0000e-04
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5649 - loss: 1.0456 - val_accuracy: 0.5000 - val_loss: 1.1431 - learning_rate: 5.0000e-04
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5649 - loss: 1.0421 - val_accuracy: 0.5000 - val_loss: 1.1395 - learning_rate: 5.0000e-04
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5475 - loss: 1.0387 - val_accuracy: 0.5000 - val_loss: 1.1359 - learning_rate: 5.0000e-04
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5475 - loss: 1.0353 - val_accuracy: 0.5000 - val_loss: 1.1324 - learning_rate: 5.0000e-04
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5417 - loss: 1.0319 - val_accuracy: 0.4881 - val_loss: 1.1289 - learning_rate: 5.0000e-04
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5185 - loss: 1.0285 - val_accuracy: 0.4881 - val_loss: 1.1255 - learning_rate: 5.0000e-04
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5185 - loss: 1.0251 - val_accuracy: 0.4881 - val_loss: 1.1221 - learning_rate: 5.0000e-04
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5128 - loss: 1.0218 - val_accuracy: 0.4881 - val_loss: 1.1188 - learning_rate: 5.0000e-04
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5128 - loss: 1.0186 - val_accuracy: 0.4881 - val_loss: 1.1156 - learning_rate: 5.0000e-04
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5128 - loss: 1.0153 - val_accuracy: 0.4881 - val_loss: 1.1124 - learning_rate: 5.0000e-04
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5107 - loss: 1.0121 - val_accuracy: 0.4881 - val_loss: 1.1092 - learning_rate: 5.0000e-04
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5107 - loss: 1.0089 - val_accuracy: 0.5000 - val_loss: 1.1062 - learning_rate: 5.0000e-04
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5261 - loss: 1.0058 - val_accuracy: 0.5119 - val_loss: 1.1032 - learning_rate: 5.0000e-04
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5318 - loss: 1.0027 - val_accuracy: 0.5119 - val_loss: 1.1002 - learning_rate: 5.0000e-04
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5415 - loss: 0.9996 - val_accuracy: 0.5119 - val_loss: 1.0974 - learning_rate: 5.0000e-04
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5415 - loss: 0.9965 - val_accuracy: 0.5119 - val_loss: 1.0946 - learning_rate: 5.0000e-04
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5415 - loss: 0.9935 - val_accuracy: 0.5119 - val_loss: 1.0919 - learning_rate: 5.0000e-04
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5415 - loss: 0.9904 - val_accuracy: 0.5119 - val_loss: 1.0891 - learning_rate: 5.0000e-04
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5590 - loss: 0.9874 - val_accuracy: 0.5119 - val_loss: 1.0865 - learning_rate: 5.0000e-04
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5590 - loss: 0.9844 - val_accuracy: 0.5119 - val_loss: 1.0838 - learning_rate: 5.0000e-04
# Epoch 43/50
# ...
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5158 - loss: 1.0871 - val_accuracy: 0.4762 - val_loss: 1.1621 - learning_rate: 5.0000e-04
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5119 - loss: 1.0741 - val_accuracy: 0.4762 - val_loss: 1.1492 - learning_rate: 5.0000e-04
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5196 - loss: 1.0621 - val_accuracy: 0.4643 - val_loss: 1.1379 - learning_rate: 5.0000e-04
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5208 - loss: 1.0511 - val_accuracy: 0.4762 - val_loss: 1.1268 - learning_rate: 5.0000e-04
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5158 - loss: 1.0409 - val_accuracy: 0.4762 - val_loss: 1.1156 - learning_rate: 5.0000e-04
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5179 - loss: 1.0312 - val_accuracy: 0.4881 - val_loss: 1.1045 - learning_rate: 5.0000e-04
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5372 - loss: 1.0218 - val_accuracy: 0.4881 - val_loss: 1.0939 - learning_rate: 5.0000e-04
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5532 - loss: 1.0127 - val_accuracy: 0.4881 - val_loss: 1.0838 - learning_rate: 5.0000e-04
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5523 - loss: 1.0039 - val_accuracy: 0.4881 - val_loss: 1.0740 - learning_rate: 5.0000e-04
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5543 - loss: 0.9953 - val_accuracy: 0.4881 - val_loss: 1.0645 - learning_rate: 5.0000e-04
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5456 - loss: 0.9868 - val_accuracy: 0.4881 - val_loss: 1.0554 - learning_rate: 5.0000e-04
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5554 - loss: 0.9786 - val_accuracy: 0.4881 - val_loss: 1.0464 - learning_rate: 5.0000e-04
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5621 - loss: 0.9707 - val_accuracy: 0.4881 - val_loss: 1.0377 - learning_rate: 5.0000e-04
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5725 - loss: 0.9629 - val_accuracy: 0.4881 - val_loss: 1.0293 - learning_rate: 5.0000e-04
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5780 - loss: 0.9554 - val_accuracy: 0.4881 - val_loss: 1.0212 - learning_rate: 5.0000e-04
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5802 - loss: 0.9480 - val_accuracy: 0.4881 - val_loss: 1.0132 - learning_rate: 5.0000e-04
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5781 - loss: 0.9409 - val_accuracy: 0.4881 - val_loss: 1.0055 - learning_rate: 5.0000e-04
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5680 - loss: 0.9338 - val_accuracy: 0.5000 - val_loss: 0.9981 - learning_rate: 5.0000e-04
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5647 - loss: 0.9270 - val_accuracy: 0.5000 - val_loss: 0.9909 - learning_rate: 5.0000e-04
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5781 - loss: 0.9203 - val_accuracy: 0.5000 - val_loss: 0.9839 - learning_rate: 5.0000e-04
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5856 - loss: 0.9138 - val_accuracy: 0.5000 - val_loss: 0.9771 - learning_rate: 5.0000e-04
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5856 - loss: 0.9074 - val_accuracy: 0.5000 - val_loss: 0.9705 - learning_rate: 5.0000e-04
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5949 - loss: 0.9011 - val_accuracy: 0.5000 - val_loss: 0.9640 - learning_rate: 5.0000e-04
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5994 - loss: 0.8950 - val_accuracy: 0.5000 - val_loss: 0.9578 - learning_rate: 5.0000e-04
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6122 - loss: 0.8890 - val_accuracy: 0.5119 - val_loss: 0.9518 - learning_rate: 5.0000e-04
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6187 - loss: 0.8831 - val_accuracy: 0.5119 - val_loss: 0.9460 - learning_rate: 5.0000e-04
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6233 - loss: 0.8773 - val_accuracy: 0.5119 - val_loss: 0.9403 - learning_rate: 5.0000e-04
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6233 - loss: 0.8717 - val_accuracy: 0.5238 - val_loss: 0.9347 - learning_rate: 5.0000e-04
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6249 - loss: 0.8662 - val_accuracy: 0.5238 - val_loss: 0.9292 - learning_rate: 5.0000e-04
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6271 - loss: 0.8609 - val_accuracy: 0.5357 - val_loss: 0.9240 - learning_rate: 5.0000e-04
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6289 - loss: 0.8556 - val_accuracy: 0.5357 - val_loss: 0.9188 - learning_rate: 5.0000e-04
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6233 - loss: 0.8505 - val_accuracy: 0.5357 - val_loss: 0.9138 - learning_rate: 5.0000e-04
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6280 - loss: 0.8455 - val_accuracy: 0.5357 - val_loss: 0.9088 - learning_rate: 5.0000e-04
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6309 - loss: 0.8405 - val_accuracy: 0.5357 - val_loss: 0.9040 - learning_rate: 5.0000e-04
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6309 - loss: 0.8356 - val_accuracy: 0.5357 - val_loss: 0.8992 - learning_rate: 5.0000e-04
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6309 - loss: 0.8309 - val_accuracy: 0.5357 - val_loss: 0.8945 - learning_rate: 5.0000e-04
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6326 - loss: 0.8262 - val_accuracy: 0.5357 - val_loss: 0.8900 - learning_rate: 5.0000e-04
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6271 - loss: 0.8215 - val_accuracy: 0.5357 - val_loss: 0.8856 - learning_rate: 5.0000e-04
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6325 - loss: 0.8169 - val_accuracy: 0.5595 - val_loss: 0.8813 - learning_rate: 5.0000e-04
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6338 - loss: 0.8123 - val_accuracy: 0.5595 - val_loss: 0.8770 - learning_rate: 5.0000e-04
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6338 - loss: 0.8078 - val_accuracy: 0.5595 - val_loss: 0.8730 - learning_rate: 5.0000e-04
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6349 - loss: 0.8034 - val_accuracy: 0.5595 - val_loss: 0.8690 - learning_rate: 5.0000e-04
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6375 - loss: 0.7990 - val_accuracy: 0.5595 - val_loss: 0.8652 - learning_rate: 5.0000e-04
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6385 - loss: 0.7947 - val_accuracy: 0.5714 - val_loss: 0.8614 - learning_rate: 5.0000e-04
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6337 - loss: 0.7904 - val_accuracy: 0.5714 - val_loss: 0.8578 - learning_rate: 5.0000e-04
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6311 - loss: 0.7863 - val_accuracy: 0.5714 - val_loss: 0.8543 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5267 - loss: 1.2854 - val_accuracy: 0.5714 - val_loss: 1.1537 - learning_rate: 5.0000e-04
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5302 - loss: 1.1830 - val_accuracy: 0.5833 - val_loss: 1.1360 - learning_rate: 5.0000e-04
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5265 - loss: 1.1440 - val_accuracy: 0.5833 - val_loss: 1.1150 - learning_rate: 5.0000e-04
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5497 - loss: 1.1211 - val_accuracy: 0.5833 - val_loss: 1.0965 - learning_rate: 5.0000e-04
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5561 - loss: 1.1029 - val_accuracy: 0.6429 - val_loss: 1.0822 - learning_rate: 5.0000e-04
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5674 - loss: 1.0875 - val_accuracy: 0.6429 - val_loss: 1.0704 - learning_rate: 5.0000e-04
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5739 - loss: 1.0741 - val_accuracy: 0.6667 - val_loss: 1.0599 - learning_rate: 5.0000e-04
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5830 - loss: 1.0621 - val_accuracy: 0.6548 - val_loss: 1.0500 - learning_rate: 5.0000e-04
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5928 - loss: 1.0509 - val_accuracy: 0.6667 - val_loss: 1.0405 - learning_rate: 5.0000e-04
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5821 - loss: 1.0402 - val_accuracy: 0.6786 - val_loss: 1.0314 - learning_rate: 5.0000e-04
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5844 - loss: 1.0299 - val_accuracy: 0.7024 - val_loss: 1.0227 - learning_rate: 5.0000e-04
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5960 - loss: 1.0201 - val_accuracy: 0.6905 - val_loss: 1.0142 - learning_rate: 5.0000e-04
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5996 - loss: 1.0105 - val_accuracy: 0.6905 - val_loss: 1.0061 - learning_rate: 5.0000e-04
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5931 - loss: 1.0013 - val_accuracy: 0.6905 - val_loss: 0.9982 - learning_rate: 5.0000e-04
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6023 - loss: 0.9922 - val_accuracy: 0.6667 - val_loss: 0.9905 - learning_rate: 5.0000e-04
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6109 - loss: 0.9834 - val_accuracy: 0.6310 - val_loss: 0.9831 - learning_rate: 5.0000e-04
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6179 - loss: 0.9748 - val_accuracy: 0.6310 - val_loss: 0.9760 - learning_rate: 5.0000e-04
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6195 - loss: 0.9665 - val_accuracy: 0.6310 - val_loss: 0.9692 - learning_rate: 5.0000e-04
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6151 - loss: 0.9583 - val_accuracy: 0.6310 - val_loss: 0.9625 - learning_rate: 5.0000e-04
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6151 - loss: 0.9504 - val_accuracy: 0.6190 - val_loss: 0.9561 - learning_rate: 5.0000e-04
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6160 - loss: 0.9426 - val_accuracy: 0.6190 - val_loss: 0.9499 - learning_rate: 5.0000e-04
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6220 - loss: 0.9349 - val_accuracy: 0.6071 - val_loss: 0.9438 - learning_rate: 5.0000e-04
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6274 - loss: 0.9273 - val_accuracy: 0.5952 - val_loss: 0.9380 - learning_rate: 5.0000e-04
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6377 - loss: 0.9199 - val_accuracy: 0.5952 - val_loss: 0.9323 - learning_rate: 5.0000e-04
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6377 - loss: 0.9127 - val_accuracy: 0.5952 - val_loss: 0.9268 - learning_rate: 5.0000e-04
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6377 - loss: 0.9056 - val_accuracy: 0.5952 - val_loss: 0.9215 - learning_rate: 5.0000e-04
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6387 - loss: 0.8987 - val_accuracy: 0.5833 - val_loss: 0.9163 - learning_rate: 5.0000e-04
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6571 - loss: 0.8919 - val_accuracy: 0.5714 - val_loss: 0.9113 - learning_rate: 5.0000e-04
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6519 - loss: 0.8853 - val_accuracy: 0.5833 - val_loss: 0.9065 - learning_rate: 5.0000e-04
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6514 - loss: 0.8788 - val_accuracy: 0.5833 - val_loss: 0.9018 - learning_rate: 5.0000e-04
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6514 - loss: 0.8724 - val_accuracy: 0.5833 - val_loss: 0.8973 - learning_rate: 5.0000e-04
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6504 - loss: 0.8662 - val_accuracy: 0.5833 - val_loss: 0.8929 - learning_rate: 5.0000e-04
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6466 - loss: 0.8600 - val_accuracy: 0.5833 - val_loss: 0.8887 - learning_rate: 5.0000e-04
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6512 - loss: 0.8540 - val_accuracy: 0.5952 - val_loss: 0.8847 - learning_rate: 5.0000e-04
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6443 - loss: 0.8481 - val_accuracy: 0.5833 - val_loss: 0.8808 - learning_rate: 5.0000e-04
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6490 - loss: 0.8424 - val_accuracy: 0.5952 - val_loss: 0.8770 - learning_rate: 5.0000e-04
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6547 - loss: 0.8367 - val_accuracy: 0.5952 - val_loss: 0.8734 - learning_rate: 5.0000e-04
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6547 - loss: 0.8312 - val_accuracy: 0.5952 - val_loss: 0.8699 - learning_rate: 5.0000e-04
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6647 - loss: 0.8257 - val_accuracy: 0.5952 - val_loss: 0.8666 - learning_rate: 5.0000e-04
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6645 - loss: 0.8204 - val_accuracy: 0.5952 - val_loss: 0.8635 - learning_rate: 5.0000e-04
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6684 - loss: 0.8151 - val_accuracy: 0.6071 - val_loss: 0.8604 - learning_rate: 5.0000e-04
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6721 - loss: 0.8099 - val_accuracy: 0.6190 - val_loss: 0.8574 - learning_rate: 5.0000e-04
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6782 - loss: 0.8049 - val_accuracy: 0.6190 - val_loss: 0.8545 - learning_rate: 5.0000e-04
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6909 - loss: 0.8001 - val_accuracy: 0.6190 - val_loss: 0.8517 - learning_rate: 5.0000e-04
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6887 - loss: 0.7953 - val_accuracy: 0.6071 - val_loss: 0.8490 - learning_rate: 5.0000e-04
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6882 - loss: 0.7907 - val_accuracy: 0.6190 - val_loss: 0.8463 - learning_rate: 5.0000e-04
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6864 - loss: 0.7862 - val_accuracy: 0.6190 - val_loss: 0.8438 - learning_rate: 5.0000e-04
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6980 - loss: 0.7818 - val_accuracy: 0.6190 - val_loss: 0.8413 - learning_rate: 5.0000e-04
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7076 - loss: 0.7775 - val_accuracy: 0.6071 - val_loss: 0.8389 - learning_rate: 5.0000e-04
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7114 - loss: 0.7733 - val_accuracy: 0.6071 - val_loss: 0.8366 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
#
# --- Training Base Model: XGBoost ---
#
# --- Training Meta-Classifier: RF ---
# Metrics for Stacking Ensemble (RF):
# Test Accuracy: 0.7256
# Test F1 Score: 0.7253
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class_0       0.81      0.65      0.72       118
#      Class_1       0.66      0.81      0.73        97
#
#     accuracy                           0.73       215
#    macro avg       0.73      0.73      0.73       215
# weighted avg       0.74      0.73      0.73       215
# Backtest Results: {'total_return_pct': np.float64(456.4628173927102), 'benchmark_return_pct': np.float64(-40.05477397617972)}
#
# Final Results:
#     model_name  test_accuracy  test_f1_weighted  backtest_return_pct  \
# 0  Stacking_RF         0.7256            0.7253             456.4628
#
#    benchmark_return_pct
# 0              -40.0548
